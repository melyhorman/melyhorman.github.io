# %% [markdown]
# <a href="https://colab.research.google.com/github/melyhorman/melyhorman.github.io/blob/main/Salinan_dari_Salinan_dari_Salinan_dari_VI_Revou_X_TELKOM_OCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bagian Baru

# %% [markdown]
# #1 . Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #2 . Load File

# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/FEB26_FSDANEXT_Bellatrix/FINAL CLIENT SEGMENTATION w channel ( Updated).csv',
    sep=';'
)

# %%
df.head()
# Out:
#   user_id             user_name  total_transactions  total_revenue  \
# 0  user_3        CV Wisata Indo               24635        5207360
# 1  user_2     PT Dana Nusantara               24518        5198910
# 2  user_1     CV Land Sejahtera               24496        5125530
# 3  user_4  PT Konektivitas Indo                6230        1276070
# 4  user_5    PT Karya Sejahtera                6198        1310570
#
#   engagement_rate_pct success_rate_pct  total_channels_used favorite_channel  \
# 0              37,91%           79,57%                    4         WhatsApp
# 1              38,54%           79,87%                    4         WhatsApp
# 2              38,67%           79,32%                    4         WhatsApp
# 3              38,25%           78,88%                    4         WhatsApp
# 4              38,33%           79,27%                    4         WhatsApp
#
#       final_segment
# 0  At-Risk Accounts
# 1     Power Clients
# 2     Power Clients
# 3  Steady Operators
# 4  Steady Operators

# %%
print(df)
# Out:
#     user_id             user_name  total_transactions  total_revenue  \
# 0    user_3        CV Wisata Indo               24635        5207360
# 1    user_2     PT Dana Nusantara               24518        5198910
# 2    user_1     CV Land Sejahtera               24496        5125530
# 3    user_4  PT Konektivitas Indo                6230        1276070
# 4    user_5    PT Karya Sejahtera                6198        1310570
# 5    user_7   PT Retail Sejahtera                6132        1327690
# 6    user_8  PT Belajar Nusantara                6117        1284620
# 7    user_6   PT Logistik Mandiri                6010        1294970
# 8   user_16   PT Estate Sejahtera                1593         339010
# 9   user_18      CV Jalan Mandiri                1573         344080
# 10  user_11   PT Travel Nusantara                1559         340730
# 11  user_20         CV Hotel Jaya                1554         342240
# 12  user_19         CV Niaga Indo                1552         336210
# 13  user_13       PT Saham Global                1530         335960
# 14  user_10          PT Mart Jaya                1525         323700
# 15  user_14    CV Hotel Nusantara                1523         305880
# 16   user_9       PT Citra Global                1519         317510
# 17  user_17         PT Karya Jaya                1510         315770
# 18  user_15        PT Edu Mandiri                1488         318840
# 19  user_12          CV Mart Indo                1487         300770
#
#    engagement_rate_pct success_rate_pct  total_channels_used favorite_channel  \
# 0               37,91%           79,57%                    4         WhatsApp
# 1               38,54%           79,87%                    4         WhatsApp
# 2               38,67%           79,32%                    4         WhatsApp
# 3               38,25%           78,88%                    4         WhatsApp
# 4               38,33%           79,27%                    4         WhatsApp
# 5               38,99%           79,78%                    4         WhatsApp
# 6               38,09%           79,34%                    4         WhatsApp
# 7               38,14%           79,45%                    4         WhatsApp
# 8               37,92%           79,91%                    4         WhatsApp
# 9               37,95%           79,85%                    4         WhatsApp
# 10              36,95%           79,47%                    4         WhatsApp
# 11              38,67%           80,31%                    4         WhatsApp
# 12              40,85%           79,83%                    4         WhatsApp
# 13              37,58%           79,87%                    4         WhatsApp
# 14              36,79%           78,89%                    4         WhatsApp
# 15              39,40%           80,24%                    4         WhatsApp
# 16              38,78%           79,86%                    4         WhatsApp
# 17              37,62%           79,40%                    4         WhatsApp
# 18              39,85%           79,57%                    4         WhatsApp
# 19              39,14%           79,15%                    4         WhatsApp
#
#        final_segment
# 0   At-Risk Accounts
# 1      Power Clients
# 2      Power Clients
# 3   Steady Operators
# 4   Steady Operators
# 5   Steady Operators
# 6   Steady Operators
# 7   Steady Operators
# 8   At-Risk Accounts
# 9   At-Risk Accounts
# 10  At-Risk Accounts
# 11  At-Risk Accounts
# 12  Growth Potential
# 13  At-Risk Accounts
# 14  At-Risk Accounts
# 15  Growth Potential
# 16  At-Risk Accounts
# 17  At-Risk Accounts
# 18  Growth Potential
# 19  Growth Potential

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['user_id', 'user_name', 'total_transactions', 'total_revenue',
#        'engagement_rate_pct', 'success_rate_pct', 'total_channels_used',
#        'favorite_channel', 'final_segment'],
#       dtype='object')

# %% [markdown]
# #3 . Data Inspection

# %%
df.dtypes
# Out:
# user_id                object
# user_name              object
# total_transactions      int64
# total_revenue           int64
# engagement_rate_pct    object
# success_rate_pct       object
# total_channels_used     int64
# favorite_channel       object
# final_segment          object
# dtype: object

# %%
numeric_cols_thousands_separator = [
    'total_transactions',
    'total_revenue'
]

numeric_cols_percentage = [
    'engagement_rate_pct',
    'success_rate_pct'
]

for col in numeric_cols_thousands_separator:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace('.', '', regex=False) # Remove thousands separator
        .astype(float)
    )

for col in numeric_cols_percentage:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace('%', '', regex=False) # Remove percentage sign
        .str.replace(',', '.', regex=False) # Replace comma decimal with dot decimal
        .astype(float)
    )

# %%
# Sanity Check
df.dtypes
# Out:
# user_id                 object
# user_name               object
# total_transactions     float64
# total_revenue          float64
# engagement_rate_pct    float64
# success_rate_pct       float64
# total_channels_used      int64
# favorite_channel        object
# final_segment           object
# dtype: object

# %% [markdown]
# #4 . Feature Selection

# %%
features = df[[
    'total_transactions',
    'total_revenue',
    'engagement_rate_pct',
    'success_rate_pct'
]]

# %% [markdown]
# #5 . Standardization

# %%
scaler = StandardScaler()

scaled_features = scaler.fit_transform(features)

# %% [markdown]
# #6  . Elbow Method

# %%
inertia = []

K_range = range(1, 10)

for k in K_range:
    km = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    km.fit(scaled_features)

    inertia.append(km.inertia_)

# %%
plt.figure(figsize=(8,5))

plt.plot(K_range, inertia, marker='o')

plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')

plt.savefig('elbow_method.png',
            bbox_inches='tight')

plt.show()

# %% [markdown]
# #7 . Kmeans Clustering

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10

)

df['cluster'] = kmeans.fit_predict(scaled_features)
df[['user_name', 'final_segment', 'cluster']]
# Out:
#                user_name     final_segment  cluster
# 0         CV Wisata Indo  At-Risk Accounts        0
# 1      PT Dana Nusantara     Power Clients        0
# 2      CV Land Sejahtera     Power Clients        0
# 3   PT Konektivitas Indo  Steady Operators        2
# 4     PT Karya Sejahtera  Steady Operators        2
# 5    PT Retail Sejahtera  Steady Operators        1
# 6   PT Belajar Nusantara  Steady Operators        2
# 7    PT Logistik Mandiri  Steady Operators        2
# 8    PT Estate Sejahtera  At-Risk Accounts        1
# 9       CV Jalan Mandiri  At-Risk Accounts        1
# 10   PT Travel Nusantara  At-Risk Accounts        2
# 11         CV Hotel Jaya  At-Risk Accounts        1
# 12         CV Niaga Indo  Growth Potential        3
# 13       PT Saham Global  At-Risk Accounts        1
# 14          PT Mart Jaya  At-Risk Accounts        2
# 15    CV Hotel Nusantara  Growth Potential        1
# 16       PT Citra Global  At-Risk Accounts        1
# 17         PT Karya Jaya  At-Risk Accounts        2
# 18        PT Edu Mandiri  Growth Potential        3
# 19          CV Mart Indo  Growth Potential        2

# %%
df.to_csv('final_client_segmentation.csv', index=False)

# %% [markdown]
# Rule-based segmentation was validated using KMeans clustering to identify natural behavioral grouping patterns among enterprise clients.

# %% [markdown]
# #8  .Silhouette Score

# %%
from sklearn.metrics import silhouette_score

# %%
score = silhouette_score(scaled_features, df['cluster'])

print("Silhouette Score:", round(score, 3))
# Out:
# Silhouette Score: 0.409

# %% [markdown]
# #7 . Visualization

# %%
plt.figure(figsize=(12,8))

plt.scatter(
    df['total_transactions'],
    df['engagement_rate_pct'],
    c=df['cluster'],   # ORIGINAL KMeans cluster coloring
    s=250
)

plt.xlabel('Total Transactions')
plt.ylabel('Engagement Rate')
plt.title('Client Clustering')

plt.show()

# %% [markdown]
# Behavioral clusters remain highly aligned with rule-based segmentation outputs, indicating stable user activity patterns across enterprise clients.
# Behavioral clustering validation confirms similar operational patterns across high-value, retention-risk, and low-activity client groups.

# %%
#PCA VISUALIZATION
from sklearn.decomposition import PCA

# Reduce dimension
pca = PCA(n_components=2)

pca_features = pca.fit_transform(scaled_features)

# Create PCA dataframe
pca_df = pd.DataFrame(
    data=pca_features,
    columns=['PC1', 'PC2']
)

pca_df['cluster'] = df['cluster']
pca_df['user_name'] = df['user_name']

# %%
plt.figure(figsize=(12,8))

scatter = plt.scatter(
    pca_df['PC1'],
    pca_df['PC2'],
    c=pca_df['cluster'],
    s=120
)

for i, txt in enumerate(pca_df['user_name']):
    plt.annotate(
        txt,
        (pca_df['PC1'][i], pca_df['PC2'][i]),
        fontsize=8
    )

plt.title('Client Behavioral Clustering (PCA)')

plt.xlabel('Behavioral Pattern Dimension 1')
plt.ylabel('Behavioral Pattern Dimension 2')

plt.savefig('pca_cluster_visualization.png',
            bbox_inches='tight')


plt.show()

# %% [markdown]
# #9 . Cluster Intrepretation

# %%
df.groupby('cluster')[[
    'total_transactions',
    'total_revenue',
    'engagement_rate_pct',
    'success_rate_pct'
]].mean()
# Out:
#          total_transactions  total_revenue  engagement_rate_pct  \
# cluster
# 0              24549.666667   5.177267e+06            38.373333
# 1               2203.428571   4.731957e+05            38.470000
# 2               3829.500000   8.059000e+05            37.913750
# 3               1520.000000   3.275250e+05            40.350000
#
#          success_rate_pct
# cluster
# 0               79.586667
# 1               79.974286
# 2               79.231250
# 3               79.700000

# %%
THANK YOU
# Out:
#   File "/tmp/ipykernel_13184/482129816.py", line 1
#     THANK YOU
#           ^
# SyntaxError: invalid syntax
